# %% [markdown]
# ## MariaDB(MySQL)와 파이썬 연동하기
# - pymysql: 파이썬-DB 연동을 지원하는 라이브러리
# - 파이썬으로 DB를 변경시킬 수 있고, DB의 데이터를 불러와 데이터 분석 및 시각화 등을 수월하게 진행할 수 있음

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\agnes\anaconda3\lib\site-packages (1.1.2)

# %%
import pymysql

# %% [markdown]
# ### DB와 파이썬 연결 및 커서 객체 생성

# %%
# host: IP주소(로컬)
# user: 사용자명(HeidiSQL에서 사용자 이름과 동일)
# db: DB명칭
# charset='utf8': 한글 인코딩(코드를 한글 문자로 변경)
conn = pymysql.connect(host="127.0.0.1", user="root", password="1234", db="person", charset="utf8")

# %%
# 쿼리문의 실행 결과를 담아줄 커서 객체 생성
cur = conn.cursor()

# %%
# execute: 쿼리문을 실행해주는 함수 (문자열로 SQL문을 입력)
temp = cur.execute('SHOW DATABASES')
temp

# 리턴값으로는 영향을 받은 행 수를 반환함
# Out:
# 5

# %%
# fetchall: 쿼리 실행 결과 출력 (튜플로 출력됨)
cur.fetchall()
# Out:
# (('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('person',),
#  ('sys',))

# %%
print(cur.execute('SHOW TABLES'))
print(cur.fetchall())
# Out:
# 1
# (('member_list',),)

# %%
# 편의상 address부터 우측 4개 컬럼 삭제
cur.execute('ALTER TABLE member_list DROP address, DROP rating, DROP first_purchase, DROP coupon')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 편의상 address부터 우측 4개 컬럼 삭제
# ----> 2 cur.execute('ALTER TABLE member_list DROP address, DROP rating, DROP first_purchase, DROP coupon')
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1091, "Can't DROP COLUMN `address`; check that it exists")

# %% [markdown]
# ### 1. SELECT문 활용

# %%
sql = 'SELECT * FROM member_list'
print(cur.execute(sql))
cur.fetchall()
# Out:
# 9
# ((1, '최성우', '남', '28', datetime.date(2024, 1, 1)),
#  (2, '김민지', '여', '26', datetime.date(2024, 1, 15)),
#  (4, '이몽룡', '남', '22', datetime.date(2024, 2, 11)),
#  (5, '김현지', '여', '30', datetime.date(2024, 3, 1)),
#  (6, '윈터', '여', '23', datetime.date(2024, 2, 15)),
#  (7, '카리나', '여', '24', datetime.date(2024, 2, 13)),
#  (8, '지젤', '여', '23', datetime.date(2024, 2, 10)),
#  (9, '김민정', '여', '100', datetime.date(2026, 1, 19)),
#  (10, '타민', '남', '20', datetime.date(2026, 1, 19)))

# %%
# 특정 테이블, 컬럼의 데이터 전체 조회 함수 선언
def search_data(table, *columns):
    cur = conn.cursor()
    # 가변매개변수 columns는 튜플로 저장되기 때문에, 복수개의 컬럼명을 문자열로 이어줌 (join)
    sql = f"SELECT {','.join(columns)} FROM {table}"
    cur.execute(sql)

    return cur.fetchall()

# %%
search_data("member_list", "No", "name")
# Out:
# ((1, '최성우'),
#  (2, '김민지'),
#  (4, '이몽룡'),
#  (5, '김현지'),
#  (6, '윈터'),
#  (7, '카리나'),
#  (8, '지젤'),
#  (9, '김민정'),
#  (10, '타민'))

# %% [markdown]
# ### 2. INSERT문 활용

# %%
no = input("번호를 입력하세요(정수 입력) : ")
name = input("이름을 입력하세요(문자열 입력) : ")
gender = input("성별을 입력하세요(남,여 중 입력) : ")
age = input("나이를 입력하세요(정수 입력) : ")
join_date = input("가입일을 입력하세요(YYYY-MM-DD 입력) : ")

# 전체 다 문자열로 들어가긴 하지만, db에서 문자로 인지하게 하려면 문자열은 '' 감싸줘야 함
sql = f"INSERT INTO member_list VALUES({no},'{name}','{gender}',{age},'{join_date}')"

cur.execute(sql)
# Out:
# 번호를 입력하세요(정수 입력) :  9
# 이름을 입력하세요(문자열 입력) :  김민정
# 성별을 입력하세요(남,여 중 입력) :  여
# 나이를 입력하세요(정수 입력) :  100
# 가입일을 입력하세요(YYYY-MM-DD 입력) :  2026-01-19
# 1

# %%
search_data("member_list", "*")
# Out:
# ((1, '최성우', '남', '28', datetime.date(2024, 1, 1)),
#  (2, '김민지', '여', '26', datetime.date(2024, 1, 15)),
#  (4, '이몽룡', '남', '22', datetime.date(2024, 2, 11)),
#  (5, '김현지', '여', '30', datetime.date(2024, 3, 1)),
#  (6, '윈터', '여', '23', datetime.date(2024, 2, 15)),
#  (7, '카리나', '여', '24', datetime.date(2024, 2, 13)),
#  (8, '지젤', '여', '23', datetime.date(2024, 2, 10)),
#  (9, '김민정', '여', '100', datetime.date(2026, 1, 19)))

# %%
# 변경사항을 실제 DB에 반영 (커밋)
conn.commit()

# %%
def insert_data(table):
    cur = conn.cursor()
    no = input("번호를 입력하세요(정수 입력) : ")
    name = input("이름을 입력하세요(문자열 입력) : ")
    gender = input("성별을 입력하세요(남,여 중 입력) : ")
    age = input("나이를 입력하세요(정수 입력) : ")
    join_date = input("가입일을 입력하세요(YYYY-MM-DD 입력) : ")
    
    sql = f"INSERT INTO {table} VALUES({no},'{name}','{gender}',{age},'{join_date}')"
    
    result = cur.execute(sql)
    print(f"영향을 받은 행: {result}개")
    conn.commit()

# %%
insert_data("member_list")
# Out:
# 번호를 입력하세요(정수 입력) :  10
# 이름을 입력하세요(문자열 입력) :  타민
# 성별을 입력하세요(남,여 중 입력) :  남
# 나이를 입력하세요(정수 입력) :  20
# 가입일을 입력하세요(YYYY-MM-DD 입력) :  2026-01-19
# 영향을 받은 행: 1개

# %%
search_data("member_list", "*")
# Out:
# ((1, '최성우', '남', '28', datetime.date(2024, 1, 1)),
#  (2, '김민지', '여', '26', datetime.date(2024, 1, 15)),
#  (4, '이몽룡', '남', '22', datetime.date(2024, 2, 11)),
#  (5, '김현지', '여', '30', datetime.date(2024, 3, 1)),
#  (6, '윈터', '여', '23', datetime.date(2024, 2, 15)),
#  (7, '카리나', '여', '24', datetime.date(2024, 2, 13)),
#  (8, '지젤', '여', '23', datetime.date(2024, 2, 10)),
#  (9, '김민정', '여', '100', datetime.date(2026, 1, 19)),
#  (10, '타민', '남', '20', datetime.date(2026, 1, 19)))

# %% [markdown]
# ### 3. UPDATE문 활용
# - UPDATE 사용자 정의 함수에 매개변수는 테이블명, 변경정보, 조건을 넣을 수 있도록 정의하세요.
# - No 9번 데이터의 성별을 반대로 바꿔보세요.

# %%
def update_data(table, set_clause, where_clause):
    cur = conn.cursor()
    
    sql = f"UPDATE {table} SET {set_clause} WHERE {where_clause}"

    result = cur.execute(sql)
    print(f"영향을 받은 행: {result}")
    conn.commit()

# %%
update_data("member_list", "gender = CASE WHEN gender='남' THEN '여' ELSE '남' END", "No=9")
# Out:
# 영향을 받은 행: 1

# %%
search_data("member_list", "*")
# Out:
# ((1, '최성우', '남', '28', datetime.date(2024, 1, 1)),
#  (2, '김민지', '여', '26', datetime.date(2024, 1, 15)),
#  (4, '이몽룡', '남', '22', datetime.date(2024, 2, 11)),
#  (5, '김현지', '여', '30', datetime.date(2024, 3, 1)),
#  (6, '윈터', '여', '23', datetime.date(2024, 2, 15)),
#  (7, '카리나', '여', '24', datetime.date(2024, 2, 13)),
#  (8, '지젤', '여', '23', datetime.date(2024, 2, 10)),
#  (9, '김민정', '여', '100', datetime.date(2026, 1, 19)),
#  (10, '타민', '남', '20', datetime.date(2026, 1, 19)))

# %% [markdown]
# ### 4. DELETE문 활용
# - DELETE 사용자 정의 함수에 매개변수는 테이블명, 조건을 넣을 수 있도록 정의하세요.
# - No10번 데이터를 삭제해보세요.

# %%
def delete_data(table, where_clause):
    cur = conn.cursor()

    sql = f"DELETE FROM {table} WHERE {where_clause}"

    result = cur.execute(sql)
    print(f"영향을 받은 행: {result}")
    conn.commit()

# %%
delete_data("member_list", "No=10")
# Out:
# 영향을 받은 행: 0

# %%
search_data("member_list", "*")
# Out:
# ((1, '최성우', '남', '28', datetime.date(2024, 1, 1)),
#  (2, '김민지', '여', '26', datetime.date(2024, 1, 15)),
#  (4, '이몽룡', '남', '22', datetime.date(2024, 2, 11)),
#  (5, '김현지', '여', '30', datetime.date(2024, 3, 1)),
#  (6, '윈터', '여', '23', datetime.date(2024, 2, 15)),
#  (7, '카리나', '여', '24', datetime.date(2024, 2, 13)),
#  (8, '지젤', '여', '23', datetime.date(2024, 2, 10)),
#  (9, '김민정', '여', '100', datetime.date(2026, 1, 19)))
